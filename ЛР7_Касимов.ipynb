# %% [markdown]
# <a href="https://colab.research.google.com/github/nserdyukov/AIPD/blob/main/%D0%9B%D0%A07_%D0%A1%D0%B5%D1%80%D0%B4%D1%8E%D0%BA%D0%BE%D0%B2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Практическая работа 7. Основы Numpy. Построение графиков

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# !wget https://raw.githubusercontent.com/enikolaev/IT-and-Programming/refs/heads/main/data/pract4/p4_data_24.csv
# Out:
# --2024-11-20 12:51:29--  https://raw.githubusercontent.com/enikolaev/IT-and-Programming/refs/heads/main/data/pract4/p4_data_24.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 47662 (47K) [text/plain]
# Saving to: ‘p4_data_24.csv’
#
# p4_data_24.csv      100%[===================>]  46.54K  --.-KB/s    in 0.01s
#
# 2024-11-20 12:51:29 (4.05 MB/s) - ‘p4_data_24.csv’ saved [47662/47662]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Загрузка данных из CSV-файла
df = pd.read_csv('p4_data_24.csv')

# 1. Гистограмма распределения товаров по категориям
category_counts = df['Category'].value_counts()

plt.figure(figsize=(7, 4))
category_counts.plot(kind='bar', color='lightblue')
plt.title('Распределение товаров по категориям')
plt.xlabel('Категория')
plt.ylabel('Количество товаров')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# 2. Точечный график зависимости цены от количества товаров
# Использование np.array для преобразования столбцов в массивы
count_array = np.array(df['Count'][:25])
price_array = np.array(df['Price'][:25])

plt.figure(figsize=(7, 4))
plt.scatter(count_array, price_array, alpha=0.5, c='green')
plt.title('Зависимость цены от количества товаров')
plt.xlabel('Количество товаров')
plt.ylabel('Цена')
plt.grid(True)
plt.show()
